# %% [markdown]
# ## Dataset Detective
# #### Load a dataset, display top rows, find highest value column, count missing values, share 5 insights.

# %%
import pandas as pd

# load dataset
data = pd.read_csv("data.csv")

# %%
print(data.head())
# Out:
#     Name  Age Department   Salary  Experience
# 0   John   25         IT  45000.0         2.0
# 1  Sarah   28         HR  50000.0         4.0
# 2  David   35    Finance  60000.0         8.0
# 3   Emma   30         IT  55000.0         5.0
# 4   Alex   29  Marketing  48000.0         3.0

# %%
print(data.max())
# Out:
# Name             Sophia
# Age                  35
# Department    Marketing
# Salary          62000.0
# Experience          8.0
# dtype: object

# %%
print(data.isnull().sum())
# Out:
# Name          0
# Age           0
# Department    0
# Salary        1
# Experience    1
# dtype: int64

# %% [markdown]
# #### Insights
# - The dataset shows variation in values across different columns.
# - Some columns may contain missing values, which need data cleaning.
# - The column with the highest maximum value indicates the largest measurement in the dataset.
# - The first few rows help understand the structure and type of data.
# - The dataset can be further analyzed using visualization or machine learning techniques.
