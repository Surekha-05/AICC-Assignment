# %% [markdown]
# ### Semantic Meaning
# Find 5 word pairs and explain semantic similarity.

# %% [raw]
# 1. Happy – Joyful
# These are synonyms
# Both express a positive emotional state
# Very high semantic similarity
#
# 2. Doctor – Hospital
# These are contextually related
# A doctor works in a hospital
# Moderate similarity based on association
#
# 3. Fast – Slow
# These are antonyms (opposites)
# Represent opposite speeds
# Low similarity but conceptually related
#
# 4. River – Stream
# These are closely related terms
# A stream is a smaller version of a river
# High similarity with slight difference in scale
#
# 5. Laptop – Keyboard
# These are functionally related
# A keyboard is part of a laptop
# Moderate similarity based on usage

# %% [markdown]
# - Synonyms like happy–joyful show high similarity
# - Related words like doctor–hospital show moderate similarity
# - Opposites like fast–slow show low similarity but strong relation
# - Some words are related by function or structure
